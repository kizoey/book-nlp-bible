# %% [markdown]
# # 실습 [28-1]<br>
# **실습명:  딥러닝 기반 대화 시스템**<br>
# - 비목적 지향 대화 시스템(챗봇) 실습
# - 검색 기반 대화 시스템과 생성 기반 대화시스템의 깃헙 소개

# %% [markdown]
# ### 검색 기반 대화 시스템
# 1. 대화-응답 일치 모델 데이터셋
# : "A Large Dataset for Research in Unstructured Multi-Turn Dialogue Systems."
# 2. 발화 단위 어텐션 모델
# : "Sequential Matching Network: A New Architecture for Multi-turn Response Selection in Retrieval-Based Chatbots."
# 3. Transformer 기반 모델
# : "Multi-turn response selection for chatbots with deep attention matching network"

# %% [markdown]
# ### 생성 기반 대화 시스템
# 1. Seq2seq 기반 모델: "A neural conversational model"
# 2. 계층 구조를 가지고 있는 encoder-decoder 기반 모델: "Building end-to-end dialogue systems using generative hierarchical neural network models"
