# %% [markdown]
# # 실습 [24-1]<br>
# **실습명: BERT을 활용한 KorQuAD 데이터셋 학습&평가**<br>
# - KorQuAD: QA(Question & Answering)의 데이터셋 중 하나 (한국어 Machine Reading 이해를 위해 만든 데이터셋)
# - NAVER Clova에서 제공한 자연어 처리와 관련된 대표 모델들과 task들을 한번에 처리할 수 있는 패키지인 CLaF 사용

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /root
# Out:
# /root

# %%
#1) 환경 세팅: 필요 패키지, 데이터셋 다운로드
# !git clone https://github.com/naver/claf.git
# Out:
# Cloning into 'claf'...
# remote: Enumerating objects: 3932, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 3932 (delta 38), reused 53 (delta 24), pack-reused 3825
# Receiving objects: 100% (3932/3932), 8.84 MiB | 14.87 MiB/s, done.
# Resolving deltas: 100% (2861/2861), done.

# %%
cd /root/claf
# Out:
# /root/claf

# %%
pip install -r requirements.txt

# %%
# !sh script/install_mecab.sh

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
mkdir data

# %%
cd data
# Out:
# /root/claf/data

# %%
mkdir korquad

# %%
cd korquad
# Out:
# /root/claf/data/korquad

# %%
# !wget https://korquad.github.io/dataset/KorQuAD_v1.0_train.json
# !wget https://korquad.github.io/dataset/KorQuAD_v1.0_dev.json

# %%
cd /root/claf
# Out:
# /root/claf

# %%
#2) 모델 학습
#train에 있는 argument에 base_config 주고 cuda 설정
# !python train.py --base_config korquad/bert_base_multilingual_uncased --cuda_devices '0' --batch_size 4

# %%
#3) 모델 평가
#저장된 모델의 가중치 불러와서 dev로 모델 평가
# !python eval.py /root/data/korquad/KorQuAD_v1.0_dev.json /root/claf/logs/squad_bert/checkpoint/model_48000.pkl  --cuda_devices '0'

# %% [markdown]
# python predict.py <학습 웨이트 경로> --question "질문 문장" --context "문맥 정보 입력"

# %%
#4) 모델 테스트
# !python predict.py /root/claf/logs/squad_bert/checkpoint/model_48000.pkl --question "88올림픽 개최지는?" --context "1988년 9월 17일부터 10월 2일까지 서울특별시와 경기도 일부 수도권 지역에서 개최된 하계 올림픽이자, 대회의 정식 명칭은 제24회 서울 올림픽 경기대회(Games of the XXIV Olympiad Seoul 1988)이다." --cuda_devices '0'
